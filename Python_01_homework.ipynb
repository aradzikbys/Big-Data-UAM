# %% [markdown]
# <b>1. Common chars</b>
# <br>
# Write a common_chars(string1, string2) function that returns an alphabetically ordered list of common letters from string1 and string2. Both strings will consist only of lowercase letters.

# %%
# Import library to work on strings
import string

def common_chars(string1,string2):
    l = []
    
    # Remove blank spaces & convert to lowercase letters:
    string1 = (string1.replace(' ','')).lower()
    string2 = (string2.replace(' ','')).lower()
    
    for letter1 in string1:
        for letter2 in string2:
            if letter1 == letter2 and letter1 not in l:
                l.append(letter1)
    
    # Sort list in ascending order (default)
    l.sort()
    
    return(l)

# %%
input1 = "Th is IS   a string"
input2 = "Ala Ma Kota"

# %%
common_chars(input1,input2)
# Out:
# ['a', 't']

# %% [markdown]
# <b>2. Perimeter</b>
# <br>
# Write a function (`perimeter`) which will calculate and return the perimeter of the given figure. The function takes exactly 1 argument, which is a list of 2-element tuples denoting the x and y coordinates of the vertex.

# %%
def perimeter(points):
    # Empty lists to store values - line segments, x points and y points:
    perimeter = []
    x_list = []
    y_list = []

    # Duplicate first point to last position in the list (easier to calculate last segment):
    points.append(points[0])

    # Add x, y to x_list and y_list:
    for (x,y) in points:
        x_list.append(x)
        y_list.append(y)

    # Append each segment to perimeter list:
    for n in range (0,len(x_list)-1):
        perimeter.append(((x_list[n+1] - x_list[n])**2 + (y_list[n+1] - y_list[n])**2)**0.5)
     
    return(sum(perimeter))

# %%
points = [(0,0), (0,1), (1,1), (1,0)]

# %%
perimeter(points)
# Out:
# 4.0

# %%
# https://www.geogebra.org/classic/Tt7U45Ea
points2 = [(-4, 2), (-3, 5), (-2, 4), (-2, 5), (0, 3), (0, 1), (1, 0), (5, 1), (8, 5), (5, 0), (4, -5), (3, -5), (3, -3), (2, -2), (1, -2), (1, -5), (0, -5), (0, -2), (-1, -2), (-1, -5), (-2, -5), (-2, -2), (-2, 0), (-4, 2)]

# %%
perimeter(points2)
# Out:
# 57.11484963083579

# %% [markdown]
# <b>3.0 Dog data</b>
# <br> Data about dogs and their owners has been loaded into the `dog_data` list. Each element of the list is a dictionary,
# which has 4 keys 'OwnerAge', 'Gender', 'Breed', 'DogAge' denoting the owner's age (age range), dog's gender, dog's breed, and dog's age.
# <br><br>
# An example list item:
# <br>{'OwnerAge': 60, 'Gender': 'M', 'Breed': 'Welsh Terrier', 'DogAge': 3}

# %%
# Import csv data to dog_data list:
import csv
from pathlib import Path

dog_data = []

data_file = open('dogs-data.csv', encoding='utf-8')
dog_data = csv.DictReader(data_file)
dog_data = list(dog_data)

# %%
dog_data
# Out:
# [{'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Welsh Terrier', 'DogAge': '3'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Cairn Terrier', 'DogAge': '12'},
#  {'OwnerAge': '40',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '2'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Mittelschnauzer', 'DogAge': '4'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Shih Tzu', 'DogAge': '3'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '4'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Bichon frisé', 'DogAge': '2'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Zwergdackel', 'DogAge': '12'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '9'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Bergamasker', 'DogAge': '13'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Bergamasker', 'DogAge': '10'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '13'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Pinscher', 'DogAge': '1'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '2'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Chihuahua', 'DogAge': '3'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Chihuahua', 'DogAge': '0'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'West Highland White Terrier',
#   'DogAge': '12'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Golden Retriever', 'DogAge': '1'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Weimaraner', 'DogAge': '1'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Tibetan Spaniel', 'DogAge': '1'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Leonberger', 'DogAge': '3'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Shiba Inu', 'DogAge': '11'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '0'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Beagle', 'DogAge': '4'},
#  {'OwnerAge': '999',
#   'Gender': 'M',
#   'Breed': 'Lagotto Romagnolo',
#   'DogAge': '7'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Border Terrier', 'DogAge': '3'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Magyar Viszla', 'DogAge': '9'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Prager Rattler', 'DogAge': '14'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Französische Bulldogge',
#   'DogAge': '1'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Cocker Spaniel', 'DogAge': '0'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Zwergrauhaardackel',
#   'DogAge': '5'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '9'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '3'},
#  {'OwnerAge': '999',
#   'Gender': 'M',
#   'Breed': 'Appenzeller Sennenhund',
#   'DogAge': '1'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Mops', 'DogAge': '3'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Staffordshire Bullterrier',
#   'DogAge': '9'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Grosspudel', 'DogAge': '2'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Spitz', 'DogAge': '17'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Englische Bulldogge',
#   'DogAge': '3'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'English Springer Spaniel',
#   'DogAge': '9'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Malteser', 'DogAge': '13'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Dobermann', 'DogAge': '8'},
#  {'OwnerAge': '999',
#   'Gender': 'M',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '12'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Langhaardackel', 'DogAge': '9'},
#  {'OwnerAge': '999', 'Gender': 'M', 'Breed': 'Chihuahua', 'DogAge': '7'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Chihuahua', 'DogAge': '4'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '3'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '6'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Malteser', 'DogAge': '0'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Bolonka Zwetna', 'DogAge': '2'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '5'},
#  {'OwnerAge': '80',
#   'Gender': 'M',
#   'Breed': 'Deutscher Kleinspitz',
#   'DogAge': '3'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Toypudel', 'DogAge': '13'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Terrier', 'DogAge': '12'},
#  {'OwnerAge': '40',
#   'Gender': 'M',
#   'Breed': 'Weisser Schäferhund (Berger Blanc Suisse)',
#   'DogAge': '8'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Chihuahua', 'DogAge': '3'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Zwergpudel', 'DogAge': '2'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Grosspudel', 'DogAge': '2'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Französische Bulldogge',
#   'DogAge': '2'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Spitz', 'DogAge': '1'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Foxterrier', 'DogAge': '9'},
#  {'OwnerAge': '40',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '5'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Kooikerhondje', 'DogAge': '4'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Mittelpudel', 'DogAge': '1'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Cocker Spaniel', 'DogAge': '0'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Cairn Terrier', 'DogAge': '3'},
#  {'OwnerAge': '30',
#   'Gender': 'M',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '3'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Boxer', 'DogAge': '1'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Zwergdackel', 'DogAge': '0'},
#  {'OwnerAge': '80',
#   'Gender': 'M',
#   'Breed': 'Zwergrauhaardackel',
#   'DogAge': '13'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Pudel', 'DogAge': '2'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '7'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Belgischer Schäferhund',
#   'DogAge': '11'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Bergamasker', 'DogAge': '13'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '10'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Border Collie', 'DogAge': '15'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Lagotto Romagnolo',
#   'DogAge': '5'},
#  {'OwnerAge': '80',
#   'Gender': 'M',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '12'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Dobermann', 'DogAge': '11'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '10'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Berner Sennenhund',
#   'DogAge': '7'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Chow Chow', 'DogAge': '12'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '9'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Border Terrier', 'DogAge': '10'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Mudi', 'DogAge': '4'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Boxer', 'DogAge': '0'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Papillon', 'DogAge': '10'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '7'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Dachshund', 'DogAge': '2'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Cairn Terrier', 'DogAge': '12'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Tibet Terrier', 'DogAge': '15'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Border Collie', 'DogAge': '11'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '12'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '12'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Italienisches Windspiel',
#   'DogAge': '3'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Lagotto Romagnolo',
#   'DogAge': '9'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Holländischer Schäfer',
#   'DogAge': '5'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Welsh Springer Spaniel',
#   'DogAge': '12'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '7'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Pinscher', 'DogAge': '12'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Berner Sennenhund',
#   'DogAge': '4'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '8'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '4'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '1'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Deutsche Dogge', 'DogAge': '1'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '8'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '6'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Magyar Viszla', 'DogAge': '4'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '7'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '3'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '7'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '1'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Zwergpudel', 'DogAge': '6'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Coton de Tulear', 'DogAge': '4'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Hovawart', 'DogAge': '10'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Hovawart', 'DogAge': '2'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '1'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '2'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Beagle', 'DogAge': '11'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Golden Retriever',
#   'DogAge': '13'},
#  {'OwnerAge': '30',
#   'Gender': 'M',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '4'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'English Cocker Spaniel',
#   'DogAge': '10'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Shih Tzu', 'DogAge': '2'},
#  {'OwnerAge': '30',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '5'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Hirtenhund', 'DogAge': '8'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Pinscher', 'DogAge': '5'},
#  {'OwnerAge': '30', 'Gender': 'M', 'Breed': 'Mops', 'DogAge': '0'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Soft Coated Wheaten Terrier',
#   'DogAge': '2'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Lagotto Romagnolo',
#   'DogAge': '2'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Chihuahua', 'DogAge': '4'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Prager Rattler', 'DogAge': '4'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Zwergpinscher', 'DogAge': '11'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Canaan Dog', 'DogAge': '6'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '12'},
#  {'OwnerAge': '30',
#   'Gender': 'M',
#   'Breed': 'Lagotto Romagnolo',
#   'DogAge': '0'},
#  {'OwnerAge': '40',
#   'Gender': 'M',
#   'Breed': 'Golden Retriever',
#   'DogAge': '11'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '2'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Bouvier', 'DogAge': '2'},
#  {'OwnerAge': '999',
#   'Gender': 'M',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '4'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '2'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '7'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Foxterrier', 'DogAge': '9'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Prager Rattler', 'DogAge': '1'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Prager Rattler', 'DogAge': '1'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Appenzeller Sennenhund',
#   'DogAge': '9'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '8'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Jura Laufhund', 'DogAge': '11'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Malteser', 'DogAge': '10'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Papillon', 'DogAge': '13'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '5'},
#  {'OwnerAge': '999',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '8'},
#  {'OwnerAge': '999',
#   'Gender': 'M',
#   'Breed': 'Spanischer Wasserhund',
#   'DogAge': '10'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '3'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Border Collie', 'DogAge': '13'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Border Collie', 'DogAge': '4'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '0'},
#  {'OwnerAge': '80',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '8'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Französische Bulldogge',
#   'DogAge': '7'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Bayerischer Gebirgsschweisshund',
#   'DogAge': '3'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Malteser', 'DogAge': '10'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '8'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Pinscher', 'DogAge': '12'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '5'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'American Bulldog', 'DogAge': '9'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Schnauzer', 'DogAge': '12'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '7'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Bouvier', 'DogAge': '6'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Parson Jack Russell Terrier',
#   'DogAge': '6'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '9'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '7'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '0'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '6'},
#  {'OwnerAge': '40',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '4'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Golden Retriever',
#   'DogAge': '11'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Malteser', 'DogAge': '14'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Appenzeller', 'DogAge': '16'},
#  {'OwnerAge': '40',
#   'Gender': 'M',
#   'Breed': 'Beauceron Berge de Beauce',
#   'DogAge': '9'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Bichon Havanais', 'DogAge': '14'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Foxterrier', 'DogAge': '7'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Dachshund', 'DogAge': '3'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '4'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '8'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '8'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '5'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Dachshund', 'DogAge': '5'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Rottweiler', 'DogAge': '9'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Terrier', 'DogAge': '7'},
#  {'OwnerAge': '999', 'Gender': 'M', 'Breed': 'Border Terrier', 'DogAge': '9'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Windspiel', 'DogAge': '13'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '4'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Husky', 'DogAge': '10'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Collie', 'DogAge': '7'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Irish Setter', 'DogAge': '6'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Bearded Collie', 'DogAge': '9'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '9'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '6'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Bichon', 'DogAge': '15'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Appenzeller', 'DogAge': '16'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Rottweiler', 'DogAge': '9'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '6'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '2'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '2'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '9'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '2'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '6'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Tschechoslowakischer Wolfshund',
#   'DogAge': '14'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Pudel', 'DogAge': '8'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Deutscher Wachtelhund',
#   'DogAge': '8'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Collie', 'DogAge': '3'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Cocker Spaniel', 'DogAge': '11'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Chihuahua', 'DogAge': '8'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Shih Tzu', 'DogAge': '8'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '10'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Boxer', 'DogAge': '4'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Deutscher Boxer', 'DogAge': '10'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Boxer', 'DogAge': '3'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Tervueren', 'DogAge': '13'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Parson Jack Russell Terrier',
#   'DogAge': '3'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Malteser', 'DogAge': '9'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '9'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Zwergpudel', 'DogAge': '3'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Pudel', 'DogAge': '9'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Schweizer Niederlaufhund',
#   'DogAge': '7'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'English Cocker Spaniel',
#   'DogAge': '3'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Dachshund', 'DogAge': '6'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Border Terrier', 'DogAge': '8'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Border Terrier', 'DogAge': '4'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Windspiel', 'DogAge': '15'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Windspiel', 'DogAge': '10'},
#  {'OwnerAge': '80',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '12'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Mops', 'DogAge': '5'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '5'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Bolonka Zwetna', 'DogAge': '3'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '10'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '5'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '2'},
#  {'OwnerAge': '80',
#   'Gender': 'W',
#   'Breed': 'West Highland White Terrier',
#   'DogAge': '10'},
#  {'OwnerAge': '80',
#   'Gender': 'W',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '10'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Irish Terrier', 'DogAge': '9'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Parson Russell Terrier',
#   'DogAge': '12'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '9'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Zwergpudel', 'DogAge': '11'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Tervueren', 'DogAge': '9'},
#  {'OwnerAge': '80',
#   'Gender': 'W',
#   'Breed': 'Berner Sennenhund',
#   'DogAge': '4'},
#  {'OwnerAge': '80',
#   'Gender': 'W',
#   'Breed': 'Berner Sennenhund',
#   'DogAge': '1'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Golden Retriever', 'DogAge': '4'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Groenendael', 'DogAge': '0'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Groenendael', 'DogAge': '5'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Pointer', 'DogAge': '6'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Cairn Terrier', 'DogAge': '14'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'English Springer Spaniel',
#   'DogAge': '2'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Chihuahua', 'DogAge': '0'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Malteser', 'DogAge': '11'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Bergamasker', 'DogAge': '5'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Pudel', 'DogAge': '15'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Toypudel', 'DogAge': '4'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Podenco', 'DogAge': '5'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'West Highland White Terrier',
#   'DogAge': '14'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Dachshund', 'DogAge': '2'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '10'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Parson Terrier', 'DogAge': '9'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Petit Basset Griffon Vendéen',
#   'DogAge': '9'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Golden Retriever', 'DogAge': '4'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '14'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'West Highland White Terrier',
#   'DogAge': '2'},
#  {'OwnerAge': '80',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '13'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Irish Setter', 'DogAge': '14'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Appenzeller Sennenhund',
#   'DogAge': '6'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Appenzeller Sennenhund',
#   'DogAge': '3'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Golden Retriever', 'DogAge': '5'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Hovawart', 'DogAge': '7'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Beagle', 'DogAge': '2'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '0'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Shih Tzu', 'DogAge': '5'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Malteser', 'DogAge': '1'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Toypudel', 'DogAge': '1'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Dalmatiner', 'DogAge': '2'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Toypudel', 'DogAge': '13'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Beagle', 'DogAge': '8'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '12'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Labrador', 'DogAge': '0'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Terrier', 'DogAge': '16'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Border Collie', 'DogAge': '14'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '8'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '6'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Cocker Spaniel', 'DogAge': '9'},
#  {'OwnerAge': '80',
#   'Gender': 'M',
#   'Breed': 'West Highland White Terrier',
#   'DogAge': '9'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Deutscher Boxer', 'DogAge': '3'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Pinscher', 'DogAge': '10'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Malteser', 'DogAge': '5'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Lagotto Romagnolo',
#   'DogAge': '3'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Schäfer', 'DogAge': '7'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Golden Retriever', 'DogAge': '8'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Groenendael', 'DogAge': '4'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Tervueren', 'DogAge': '11'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Rhodesian Ridgeback',
#   'DogAge': '5'},
#  {'OwnerAge': '90', 'Gender': 'M', 'Breed': 'Coton de Tulear', 'DogAge': '5'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Riesenschnauzer', 'DogAge': '2'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '7'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Hovawart', 'DogAge': '0'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Grosspudel', 'DogAge': '11'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '4'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '13'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'West Highland White Terrier',
#   'DogAge': '14'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Deutscher Boxer', 'DogAge': '11'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Scottish Terrier', 'DogAge': '8'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Scottish Terrier', 'DogAge': '1'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Tervueren', 'DogAge': '9'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Parson Jack Russell Terrier',
#   'DogAge': '14'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Foxterrier', 'DogAge': '3'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Zwergpudel', 'DogAge': '11'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Zwergrauhaardackel',
#   'DogAge': '5'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '12'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '9'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '5'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '10'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '3'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '5'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '10'},
#  {'OwnerAge': '90', 'Gender': 'W', 'Breed': 'Foxterrier', 'DogAge': '11'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '12'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Golden Retriever', 'DogAge': '1'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '3'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Australian Shepherd',
#   'DogAge': '5'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Französische Bulldogge',
#   'DogAge': '0'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Pekingese', 'DogAge': '8'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '0'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Airedale Terrier', 'DogAge': '1'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Airedale Terrier', 'DogAge': '6'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Collie', 'DogAge': '5'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '3'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '1'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Italienisches Windspiel',
#   'DogAge': '8'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '3'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Beagle', 'DogAge': '10'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'West Highland White Terrier',
#   'DogAge': '12'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Toypudel', 'DogAge': '12'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Toypudel', 'DogAge': '10'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Belgischer Schäferhund',
#   'DogAge': '14'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '0'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Cairn Terrier', 'DogAge': '2'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Miniature Bull Terrier',
#   'DogAge': '4'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Terrier', 'DogAge': '13'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '5'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Chihuahua', 'DogAge': '5'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '3'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Irish Terrier', 'DogAge': '0'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Berger des Pyrenées',
#   'DogAge': '15'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Tibet Terrier', 'DogAge': '10'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Golden Retriever', 'DogAge': '9'},
#  {'OwnerAge': '90',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '9'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '11'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Cairn Terrier', 'DogAge': '12'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Cocker Spaniel', 'DogAge': '12'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '8'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '7'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '11'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Galgo Espanol', 'DogAge': '6'},
#  {'OwnerAge': '80',
#   'Gender': 'M',
#   'Breed': 'Alpenländische Dachsbracke',
#   'DogAge': '7'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Sheltie', 'DogAge': '6'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Dobermann', 'DogAge': '14'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Malteser', 'DogAge': '4'},
#  {'OwnerAge': '30', 'Gender': 'W', 'Breed': 'Papillon', 'DogAge': '12'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Terrier', 'DogAge': '9'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Golden Retriever', 'DogAge': '8'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Italienisches Windspiel',
#   'DogAge': '3'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Windspiel', 'DogAge': '3'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Rottweiler', 'DogAge': '6'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Appenzeller', 'DogAge': '14'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Cocker Spaniel', 'DogAge': '6'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Bearded Collie', 'DogAge': '11'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Bearded Collie', 'DogAge': '8'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Bearded Collie', 'DogAge': '5'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Bearded Collie', 'DogAge': '4'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '8'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '5'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Pudel', 'DogAge': '9'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Terrier', 'DogAge': '16'},
#  {'OwnerAge': '80',
#   'Gender': 'W',
#   'Breed': 'Lagotto Romagnolo',
#   'DogAge': '2'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Samojede', 'DogAge': '0'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Bobtail (Old English Shepdog)',
#   'DogAge': '10'},
#  {'OwnerAge': '80',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '6'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Appenzeller Sennenhund',
#   'DogAge': '11'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '5'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Border Collie', 'DogAge': '8'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Spinone', 'DogAge': '12'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '13'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Bolonka Zwetna', 'DogAge': '2'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Bearded Collie', 'DogAge': '1'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '6'},
#  {'OwnerAge': '80',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '7'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '7'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Beagle', 'DogAge': '2'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Berner Sennenhund',
#   'DogAge': '6'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Border Terrier', 'DogAge': '12'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Cairn Terrier', 'DogAge': '3'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '1'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '8'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Malteser', 'DogAge': '16'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '10'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '3'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '5'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Katalanischer Hirtenhund',
#   'DogAge': '10'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '5'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Pudel', 'DogAge': '11'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Mittelpudel', 'DogAge': '10'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Cairn Terrier', 'DogAge': '2'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Podenco', 'DogAge': '3'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Parson Terrier', 'DogAge': '4'},
#  {'OwnerAge': '80',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '10'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Grosser Schweizer Sennenhund',
#   'DogAge': '2'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Alaskan Husky', 'DogAge': '10'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Bolonka Zwetna', 'DogAge': '3'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '15'},
#  {'OwnerAge': '30', 'Gender': 'W', 'Breed': 'Appenzeller', 'DogAge': '0'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '2'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '10'},
#  {'OwnerAge': '80',
#   'Gender': 'W',
#   'Breed': 'Lakeland Terrier',
#   'DogAge': '12'},
#  {'OwnerAge': '80',
#   'Gender': 'W',
#   'Breed': 'Zwergrauhaardackel',
#   'DogAge': '14'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '7'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Lagotto Romagnolo',
#   'DogAge': '5'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Spitz', 'DogAge': '14'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '14'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Cocker Spaniel', 'DogAge': '8'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Langhaardackel', 'DogAge': '9'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Rauhaar Dackel', 'DogAge': '15'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Golden Retriever', 'DogAge': '5'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '6'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Dachshund', 'DogAge': '1'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Golden Retriever', 'DogAge': '1'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Zwergschnauzer', 'DogAge': '6'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Berger de Picardie',
#   'DogAge': '4'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'West Highland White Terrier',
#   'DogAge': '12'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Sennenhund', 'DogAge': '11'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Berner Sennenhund',
#   'DogAge': '2'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '2'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Cairn Terrier', 'DogAge': '0'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Berner Sennenhund',
#   'DogAge': '8'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Airedale Terrier', 'DogAge': '5'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Chihuahua', 'DogAge': '9'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Sheltie', 'DogAge': '6'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Deutsche Dogge', 'DogAge': '1'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Pekingese', 'DogAge': '10'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Sennenhund', 'DogAge': '6'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Chinese Crested Powderpuff',
#   'DogAge': '3'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Portugiesischer Wasserhund',
#   'DogAge': '7'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '1'},
#  {'OwnerAge': '999',
#   'Gender': 'M',
#   'Breed': 'Deutscher Pinscher',
#   'DogAge': '4'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Collie', 'DogAge': '3'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Pekingese', 'DogAge': '6'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Pekingese', 'DogAge': '4'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Bolonka Zwetna', 'DogAge': '0'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Beagle', 'DogAge': '8'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '2'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '6'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '9'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Whippet', 'DogAge': '2'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '13'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Shih Tzu', 'DogAge': '7'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Coton de Tulear', 'DogAge': '10'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Dachshund', 'DogAge': '6'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '0'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Zwergpudel', 'DogAge': '12'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Münsterländer', 'DogAge': '11'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Mittelpudel', 'DogAge': '8'},
#  {'OwnerAge': '80',
#   'Gender': 'M',
#   'Breed': 'Flat Coated Retriever',
#   'DogAge': '11'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '12'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Kleiner Münsterländer',
#   'DogAge': '1'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Terrier', 'DogAge': '11'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Galgo Espanol', 'DogAge': '7'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Malteser', 'DogAge': '16'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Azawakh', 'DogAge': '6'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Chihuahua', 'DogAge': '4'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Chinese Crested', 'DogAge': '0'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Irish Setter', 'DogAge': '10'},
#  {'OwnerAge': '30',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '13'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Miniature Australian Shepherd',
#   'DogAge': '4'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Zwergrauhaardackel',
#   'DogAge': '9'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Beagle', 'DogAge': '5'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '4'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'West Highland White Terrier',
#   'DogAge': '5'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '1'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '11'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Zwergpudel', 'DogAge': '6'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Pointer', 'DogAge': '6'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Cocker Spaniel', 'DogAge': '0'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '8'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '7'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '0'},
#  {'OwnerAge': '80',
#   'Gender': 'M',
#   'Breed': 'Golden Retriever',
#   'DogAge': '11'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Bolonka Zwetna', 'DogAge': '1'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Dachshund', 'DogAge': '5'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Dachshund', 'DogAge': '4'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Malteser', 'DogAge': '1'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'English Springer Spaniel',
#   'DogAge': '8'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Bergamasker', 'DogAge': '10'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Labrador', 'DogAge': '1'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Pudel', 'DogAge': '6'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Pudel', 'DogAge': '6'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Cairn Terrier', 'DogAge': '14'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Manchester Terrier',
#   'DogAge': '6'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '12'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '11'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '9'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '6'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '3'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Pudel', 'DogAge': '4'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Schäfer', 'DogAge': '11'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Dachshund', 'DogAge': '5'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Podenco', 'DogAge': '4'},
#  {'OwnerAge': '40', 'Gender': 'M', 'Breed': 'Irish Terrier', 'DogAge': '9'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Rehpinscher', 'DogAge': '15'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Tervueren', 'DogAge': '8'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Riesenschnauzer', 'DogAge': '11'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Riesenschnauzer', 'DogAge': '7'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Berger Picard', 'DogAge': '3'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '13'},
#  {'OwnerAge': '30', 'Gender': 'M', 'Breed': 'Chihuahua', 'DogAge': '4'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '14'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Zwergpudel', 'DogAge': '11'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Collie', 'DogAge': '8'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Deutsche Dogge', 'DogAge': '6'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '12'},
#  {'OwnerAge': '90', 'Gender': 'W', 'Breed': 'Pudel', 'DogAge': '4'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Rottweiler', 'DogAge': '10'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '1'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Collie', 'DogAge': '4'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Flat Coated Retriever',
#   'DogAge': '5'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Pudel', 'DogAge': '3'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Cocker Spaniel', 'DogAge': '15'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Cocker Spaniel', 'DogAge': '6'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '8'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Toypudel', 'DogAge': '10'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Phalène', 'DogAge': '13'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Sheltie', 'DogAge': '11'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Bearded Collie', 'DogAge': '7'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '7'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Rauhaar Dackel', 'DogAge': '13'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Golden Retriever',
#   'DogAge': '13'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Chow Chow', 'DogAge': '7'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Chow Chow', 'DogAge': '7'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '4'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Appenzeller Sennenhund',
#   'DogAge': '1'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Zwergpudel', 'DogAge': '10'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Tibet Terrier', 'DogAge': '14'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Pekingese', 'DogAge': '6'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Silky Terrier', 'DogAge': '15'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Irish Soft Coated Wheaten Terrier',
#   'DogAge': '2'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '11'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '8'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Parson Jack Russell Terrier',
#   'DogAge': '4'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Golden Retriever',
#   'DogAge': '10'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '9'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '12'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '5'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Entlebucher Sennenhund',
#   'DogAge': '4'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Islandhund', 'DogAge': '0'},
#  {'OwnerAge': '80',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '6'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Rehpinscher', 'DogAge': '12'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '0'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Berner Sennenhund',
#   'DogAge': '8'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Havaneser', 'DogAge': '5'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Fila Brasileiro', 'DogAge': '0'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Maremmano', 'DogAge': '9'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '8'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Cairn Terrier', 'DogAge': '8'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '10'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '7'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Schäfer', 'DogAge': '4'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '16'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '16'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '15'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '9'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '9'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '8'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '8'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '6'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '5'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '5'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '4'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Bulldog', 'DogAge': '11'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Papillon', 'DogAge': '4'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Papillon', 'DogAge': '3'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Kromfohrländer', 'DogAge': '10'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '8'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Boxer', 'DogAge': '7'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Chow Chow', 'DogAge': '12'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Havaneser', 'DogAge': '6'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '9'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Beagle', 'DogAge': '3'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Rottweiler', 'DogAge': '5'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'West Highland White Terrier',
#   'DogAge': '5'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Bichon frisé', 'DogAge': '0'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Setter', 'DogAge': '7'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '3'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '0'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '10'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Beagle', 'DogAge': '4'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Zwergschnauzer', 'DogAge': '6'},
# ...
#   'DogAge': '11'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '14'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Appenzeller', 'DogAge': '13'},
#  {'OwnerAge': '30',
#   'Gender': 'M',
#   'Breed': 'Berner Sennenhund',
#   'DogAge': '7'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Lhasa Apso', 'DogAge': '12'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Cocker Spaniel', 'DogAge': '11'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Dachshund', 'DogAge': '16'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Australian Shepherd',
#   'DogAge': '6'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '5'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Golden Retriever', 'DogAge': '1'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Französische Bulldogge',
#   'DogAge': '9'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Rottweiler', 'DogAge': '3'},
#  {'OwnerAge': '30',
#   'Gender': 'M',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '14'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Chihuahua', 'DogAge': '1'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Appenzeller', 'DogAge': '15'},
#  {'OwnerAge': '40',
#   'Gender': 'M',
#   'Breed': "Cirneco dell'Etna",
#   'DogAge': '8'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Tibet Terrier', 'DogAge': '2'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '6'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Bergamasker', 'DogAge': '13'},
#  {'OwnerAge': '999', 'Gender': 'M', 'Breed': 'Boxer', 'DogAge': '7'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '0'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Schäfer', 'DogAge': '12'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Rauhaar Dackel', 'DogAge': '15'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Continental Bulldog',
#   'DogAge': '1'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Tervueren', 'DogAge': '2'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Beagle', 'DogAge': '3'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '0'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Groenendael', 'DogAge': '2'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '4'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Bernhardiner', 'DogAge': '9'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Golden Retriever',
#   'DogAge': '10'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Airedale Terrier', 'DogAge': '3'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Border Collie', 'DogAge': '11'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '11'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Skye Terrier', 'DogAge': '0'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Border Collie', 'DogAge': '11'},
#  {'OwnerAge': '70',
#   'Gender': 'M',
#   'Breed': 'Schweizer Laufhund',
#   'DogAge': '10'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Boxer', 'DogAge': '8'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Golden Retriever', 'DogAge': '5'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'West Highland White Terrier',
#   'DogAge': '9'},
#  {'OwnerAge': '80',
#   'Gender': 'W',
#   'Breed': 'West Highland White Terrier',
#   'DogAge': '12'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Scottish Terrier', 'DogAge': '8'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Königspudel', 'DogAge': '5'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Westgotenspitz', 'DogAge': '15'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Mittelpudel', 'DogAge': '4'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Bolonka Zwetna', 'DogAge': '4'},
#  {'OwnerAge': '80',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '7'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Dachshund', 'DogAge': '15'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '9'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '4'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Toy Pudel', 'DogAge': '12'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Papillon', 'DogAge': '12'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Bolonka Zwetna', 'DogAge': '4'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Bordeauxdogge', 'DogAge': '0'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Shih Tzu', 'DogAge': '7'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Border Collie', 'DogAge': '10'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Appenzeller', 'DogAge': '14'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Schnauzer', 'DogAge': '9'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Appenzeller', 'DogAge': '9'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '14'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '8'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Petit Basset Griffon Vendéen',
#   'DogAge': '9'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Schäfer', 'DogAge': '8'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Tibet Terrier', 'DogAge': '10'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Bearded Collie', 'DogAge': '5'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'English Springer Spaniel',
#   'DogAge': '7'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'English Cocker Spaniel',
#   'DogAge': '11'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Berner Sennenhund',
#   'DogAge': '0'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '12'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '8'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Deutscher Langhaarschäfer',
#   'DogAge': '8'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Samojede', 'DogAge': '5'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Cavalier King Charles Spaniel',
#   'DogAge': '8'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Shih Tzu', 'DogAge': '9'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Langhaardackel', 'DogAge': '7'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Bergamasker', 'DogAge': '12'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Golden Retriever', 'DogAge': '0'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'English Setter', 'DogAge': '3'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Deutsche Dogge', 'DogAge': '0'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Airedale Terrier',
#   'DogAge': '10'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Irish Wolfhound', 'DogAge': '4'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Podenco', 'DogAge': '11'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Podenco', 'DogAge': '16'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Pekingese', 'DogAge': '5'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Afghanischer Windhund',
#   'DogAge': '8'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '9'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Appenzeller', 'DogAge': '15'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Havaneser', 'DogAge': '2'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Skye Terrier', 'DogAge': '0'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Pudel', 'DogAge': '4'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Flat Coated Retriever',
#   'DogAge': '5'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '14'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Vizsla', 'DogAge': '9'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Schnauzer', 'DogAge': '14'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Mittelschnauzer', 'DogAge': '8'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Boxer', 'DogAge': '12'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Französische Bulldogge',
#   'DogAge': '0'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '16'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Galgo', 'DogAge': '8'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Mittelpudel', 'DogAge': '10'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Sheltie', 'DogAge': '10'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Vorstehhund', 'DogAge': '9'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '2'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Welsh Terrier', 'DogAge': '10'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Cocker Spaniel', 'DogAge': '14'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '7'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '1'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '1'},
#  {'OwnerAge': '80', 'Gender': 'M', 'Breed': 'Chihuahua', 'DogAge': '5'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Tervueren', 'DogAge': '5'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Appenzeller Sennenhund',
#   'DogAge': '3'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '8'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '4'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '17'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Afghanischer Windhund',
#   'DogAge': '5'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Deerhound', 'DogAge': '8'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '3'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Chihuahua', 'DogAge': '5'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Papillon', 'DogAge': '13'},
#  {'OwnerAge': '90',
#   'Gender': 'W',
#   'Breed': 'Berner Sennenhund',
#   'DogAge': '16'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Pekingese', 'DogAge': '10'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Collie', 'DogAge': '12'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Appenzeller', 'DogAge': '12'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Berner Sennenhund',
#   'DogAge': '7'},
#  {'OwnerAge': '90',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '14'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Toy Pudel', 'DogAge': '8'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Deutscher Boxer', 'DogAge': '8'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Bergamasker', 'DogAge': '10'},
#  {'OwnerAge': '90', 'Gender': 'M', 'Breed': 'Pudel', 'DogAge': '14'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Dachsbracke', 'DogAge': '10'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Scottish Terrier',
#   'DogAge': '11'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Lagotto Romagnolo',
#   'DogAge': '9'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Foxterrier', 'DogAge': '0'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '3'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Cocker Spaniel', 'DogAge': '2'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Pudel', 'DogAge': '9'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Chihuahua', 'DogAge': '6'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Pekingese', 'DogAge': '14'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Bergamasker', 'DogAge': '1'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Toypudel', 'DogAge': '9'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '5'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Mops', 'DogAge': '4'},
#  {'OwnerAge': '50',
#   'Gender': 'M',
#   'Breed': 'Deutscher Schäfer',
#   'DogAge': '3'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '2'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Welsh Corgi Pembroke',
#   'DogAge': '10'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '0'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '13'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Kooikerhondje', 'DogAge': '9'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'American Cocker Spaniel',
#   'DogAge': '7'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Malteser', 'DogAge': '2'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Galgo Espanol', 'DogAge': '10'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Chihuahua', 'DogAge': '13'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Chihuahua', 'DogAge': '0'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '10'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Pudel', 'DogAge': '3'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Bolonka Zwetna', 'DogAge': '0'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Havaneser', 'DogAge': '8'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Schäfer', 'DogAge': '12'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Tibet Terrier', 'DogAge': '1'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '14'},
#  {'OwnerAge': '40',
#   'Gender': 'W',
#   'Breed': 'Cavalier King Charles Spaniel',
#   'DogAge': '2'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '2'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Chihuahua', 'DogAge': '5'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '13'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '8'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Berner Sennenhund',
#   'DogAge': '6'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Bobtail (Old English Shepdog)',
#   'DogAge': '10'},
#  {'OwnerAge': '50',
#   'Gender': 'W',
#   'Breed': 'Labrador Retriever',
#   'DogAge': '17'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Bolonka Zwetna', 'DogAge': '6'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '8'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Border Collie', 'DogAge': '12'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Zwergpudel', 'DogAge': '8'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Rauhaar Dackel', 'DogAge': '2'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Berner Sennenhund',
#   'DogAge': '1'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Collie', 'DogAge': '9'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Dachshund', 'DogAge': '5'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Pudel', 'DogAge': '9'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Golden Retriever', 'DogAge': '3'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Airedale Terrier', 'DogAge': '2'},
#  {'OwnerAge': '80',
#   'Gender': 'W',
#   'Breed': 'Jack Russel Terrier',
#   'DogAge': '15'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Chihuahua', 'DogAge': '9'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Pekingese', 'DogAge': '7'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Breton', 'DogAge': '8'},
#  {'OwnerAge': '50', 'Gender': 'M', 'Breed': 'Irish Setter', 'DogAge': '0'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Hovawart', 'DogAge': '1'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Schäfer', 'DogAge': '8'},
#  {'OwnerAge': '70', 'Gender': 'W', 'Breed': 'Pudel', 'DogAge': '10'},
#  {'OwnerAge': '80', 'Gender': 'W', 'Breed': 'Malteser', 'DogAge': '12'},
#  {'OwnerAge': '30',
#   'Gender': 'W',
#   'Breed': 'Miniature Bull Terrier',
#   'DogAge': '1'},
#  {'OwnerAge': '70', 'Gender': 'M', 'Breed': 'Irish Setter', 'DogAge': '2'},
#  {'OwnerAge': '60', 'Gender': 'M', 'Breed': 'Boxer', 'DogAge': '9'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '10'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Bergamasker', 'DogAge': '12'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Beagle', 'DogAge': '1'},
#  {'OwnerAge': '60', 'Gender': 'W', 'Breed': 'Terrier', 'DogAge': '8'},
#  {'OwnerAge': '999', 'Gender': 'W', 'Breed': 'Bergamasker', 'DogAge': '11'},
#  {'OwnerAge': '40', 'Gender': 'W', 'Breed': 'Chihuahua', 'DogAge': '2'},
#  {'OwnerAge': '60',
#   'Gender': 'M',
#   'Breed': 'Flat Coated Retriever',
#   'DogAge': '6'},
#  {'OwnerAge': '60',
#   'Gender': 'W',
#   'Breed': 'Yorkshire Terrier',
#   'DogAge': '9'},
#  {'OwnerAge': '70',
#   'Gender': 'W',
#   'Breed': 'Flat Coated Retriever',
#   'DogAge': '9'},
#  {'OwnerAge': '50', 'Gender': 'W', 'Breed': 'Foxterrier', 'DogAge': '10'},
#  ...]

# %%
#A
# Add all dog breeds contained in dog_data to new list, `breeds`. List elements should be unique and sorted alphabetically.
breeds = []

for x in dog_data:
    if x['Breed'] not in breeds:
        breeds.append(x['Breed'])

breeds.sort()

print(len(breeds))
# Out:
# 383

# %%
#B Find the most popular dog breed for each age range (key `OwnerAge`) and save the result as the_most_popular_breed dictionary: 
# with keys as age ranges and the values as the most popular breed of dog (for a given range).

# Check what different ages are in the dog_data:
ages = []

for x in dog_data:
    if x['OwnerAge'] not in ages:
        ages.append(x['OwnerAge'])

ages.sort()

print(ages)
# Out:
# ['10', '20', '30', '40', '50', '60', '70', '80', '90', '999']

# %%
# Create new dictionary based on ages in dog_data:
the_most_popular_breed = {}
the_most_popular_breed = {x:[] for x in ages}

# %%
# Assign breeds to the list with age ranges:
for item in dog_data:
    the_most_popular_breed[item['OwnerAge']].append(item['Breed'])

# %%
# Import statistic to find mode (most frequent value) of the list in the_most_popular_breed dictionary

import statistics as stat

for age in the_most_popular_breed:
    the_most_popular_breed[age] = stat.mode(the_most_popular_breed[age])

print(the_most_popular_breed)
# Out:
# {'10': 'Yorkshire Terrier', '20': 'Chihuahua', '30': 'Chihuahua', '40': 'Chihuahua', '50': 'Labrador Retriever', '60': 'Labrador Retriever', '70': 'Labrador Retriever', '80': 'Pudel', '90': 'Pudel', '999': 'Mops'}

# %%
#C Using the statistics library (https://docs.python.org/3/library/statistics.html#)
# calculate mean, mode and age variance of the dogs.
import statistics as stat

#Create list with dog ages
dog_ages = []

for x in dog_data:
    dog_ages.append(x['DogAge'])
    
print(len(dog_data))
print(len(dog_ages)) #Healthcheck: should be the same as dog_data

#Convert list to integers:
dog_ages = [int(x) for x in dog_ages]

print(len(dog_ages)) #healthcheck
# Out:
# 53616
# 53616
# 53616

# %%
# Mean
stat.mean(dog_ages)
# Out:
# 6.046609221128022

# %%
# Mode
stat.mode(dog_ages)
# Out:
# 0

# %%
# Variance
stat.variance(dog_ages)
# Out:
# 164.45547931654204

# %%
#D Write to the file `terriers.txt` how many Terriers there are and list all the names. 
# Save the data in CSV format. Use the `csv` library.

# Create empty list to which we assign distinct terriers breeds:
terriers_list = []

for x in dog_data:
    if ('Terrier' in x['Breed']  or 'terrier' in x['Breed']) and x['Breed'] not in terriers_list:
        terriers_list.append(x['Breed'])

terriers_list.sort()
print(terriers_list)
# Out:
# ['Airedale Terrier', 'American Staffordshire Terrier', 'Australian Silky Terrier', 'Australian Terrier', 'Bedlington Terrier', 'Biewer Yorkshire Terrier', 'Border Terrier', 'Boston Terrier', 'Brasilianischer Terrier', 'Bull Terrier', 'Cairn Terrier', 'Deutscher Jagdterrier', 'English Staffordshire Terrier', 'English Toy Terrier', 'Foxterrier', 'Irish Soft Coated Wheaten Terrier', 'Irish Terrier', 'Jack Russel Terrier', 'Kerry Blue Terrier', 'Lakeland Terrier', 'Manchester Terrier', 'Miniature Bull Terrier', 'Norfolk Terrier', 'Norwich Terrier', 'Parson Jack Russell Terrier', 'Parson Russell Terrier', 'Parson Terrier', 'Pit Bull Terrier', 'Russischer schwarzer Terrier', 'Scottish Terrier', 'Silky Terrier', 'Skye Terrier', 'Soft Coated Wheaten Terrier', 'Staffordshire Bullterrier', 'Terrier', 'Tibet Terrier', 'Toyterrier', 'Tschechischer Terrier', 'Welsh Terrier', 'West Highland White Terrier', 'Yorkshire Terrier']

# %%
# Create terriers dictionary with initial count 0:
terriers = {x:0 for x in terriers_list}

# %%
# Iterate through dog_data to update terriers dictionary:
for item in dog_data:
    if item['Breed'] in terriers.keys():
        terriers[item['Breed']] +=1

# %%
# Save terriers dictionary to csv file:
with open('terriers.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Breed', 'Count'])
    for row in terriers.items():
        writer.writerow(row)
